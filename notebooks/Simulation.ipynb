# %%
using POMDPs
using OPCSPs
using POMDPToolbox

# %%
problem = gen_two_cluster_problem();

# %%
sim = HistoryRecorder()
policy = RandomPolicy(problem, rng=MersenneTwister(23))
simulate(sim, problem, policy, updater(problem), initial_belief(problem))
# Out:
# 12.815293085591897

# %%
sim = RolloutSimulator()
@time simulate(sim, problem, policy, updater(problem), initial_belief(problem))
Profile.clear()
@time @profile begin
    for i in 1:10000
        simulate(sim, problem, policy, updater(problem), initial_belief(problem))
    end
end
# Out:
#   0.000156 seconds (200 allocations: 21.828 KB)
#   0.329484 seconds (2.70 M allocations: 216.910 MB, 6.77% gc time)

# %%
import ProfileView
ProfileView.view()
# Out:
# ProfileView.ProfileData(329x14 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}:
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.549,0.0,0.271)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  ⋮                           ⋱
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)        …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)    ,Dict(0x00007fa0045983a8=>Base.Profile.LineInfo("apply_measurement","/home/zach/.julia/OPCSPs/src/MVNTools.jl",41,"",-1,false,140325244470184),0x00007fa00455447c=>Base.Profile.LineInfo("include_string","loading.jl",266,"",-1,false,140325244191868),0x00007fa00358d7cc=>Base.Profile.LineInfo("jl_gc_alloc_3w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,"",-1,true,140325227648972),0x00007fa004597c5b=>Base.Profile.LineInfo("transition","/home/zach/.julia/OPCSPs/src/pomdp.jl",71,"",-1,false,140325244468315),0x00007fa004594a55=>Base.Profile.LineInfo("advance_filter","iterator.jl",97,"",-1,false,140325244455509),0x00007fa003573792=>Base.Profile.LineInfo("jl_alloc_array_1d","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,"",-1,true,140325227542418),0x00007fa00358d379=>Base.Profile.LineInfo("jl_gc_allocobj","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,"",-1,true,140325227647865),0x00007fa004597b5b=>Base.Profile.LineInfo("unsafe_getindex","array.jl",293,"",-1,false,140325244468059),0x00007fa00351b540=>Base.Profile.LineInfo("jl_f_get_field","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,"",-1,true,140325227181376),0x00007fa003580999=>Base.Profile.LineInfo("???","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",140325227596185,"",-1,true,140325227596185),0x00007fa004596ce2=>Base.Profile.LineInfo("fill!","array.jl",193,"",-1,false,140325244464354),0x00007fa004594736=>Base.Profile.LineInfo("anonymous","/home/zach/.julia/OPCSPs/src/pomdp.jl",128,"",-1,false,140325244454710),0x00007fa00459471e=>Base.Profile.LineInfo("anonymous","/home/zach/.julia/OPCSPs/src/pomdp.jl",128,"",-1,false,140325244454686),0x00007fa00356e2f0=>Base.Profile.LineInfo("jl_get_nth_field","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,"",-1,true,140325227520752),0x00007fa0045a35f3=>Base.Profile.LineInfo("simulate","/home/zach/.julia/POMDPToolbox/src/simulators.jl",32,"",-1,false,140325244515827),0x00007fa003586169=>Base.Profile.LineInfo("???","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",140325227618665,"",-1,true,140325227618665),0x00007f9dfc365395=>Base.Profile.LineInfo("dgemm_nn","/usr/lib/libopenblas.so.0",-1,"",-1,true,140316518011797),0x00007fa004597de0=>Base.Profile.LineInfo("rand!","/home/zach/.julia/OPCSPs/src/pomdp.jl",79,"",-1,false,140325244468704),0x00007f9dfe44c70a=>Base.Profile.LineInfo("jlcall_deepcopy_internal_22020","",-1,"",-1,true,140316552513290),0x00007fa00358426f=>Base.Profile.LineInfo("???","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",140325227610735,"",-1,true,140325227610735),0x00007fa00350d6bd=>Base.Profile.LineInfo("???","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",140325227124413,"",-1,true,140325227124413),0x00007fa004599045=>Base.Profile.LineInfo("-","arraymath.jl",96,"",-1,false,140325244473413),0x00007fa0045964c0=>Base.Profile.LineInfo("create_transition_distribution","/home/zach/.julia/OPCSPs/src/pomdp.jl",9,"",-1,false,140325244462272),0x00007fa00358d33f=>Base.Profile.LineInfo("jl_gc_allocobj","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,"",-1,true,140325227647807),0x00007fa00459cc20=>Base.Profile.LineInfo("create_belief","/home/zach/.julia/OPCSPs/src/pomdp.jl",42,"",-1,false,140325244488736),0x00007fa003586160=>Base.Profile.LineInfo("???","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",140325227618656,"",-1,true,140325227618656),0x00007fa004506920=>Base.Profile.LineInfo("???","???",140325243873568,"",-1,true,140325243873568),0x00007fa003228340=>Base.Profile.LineInfo("???","/lib/x86_64-linux-gnu/libpthread.so.0",140325224088384,"",-1,true,140325224088384),0x00007fa00016995b=>Base.Profile.LineInfo("done","./intset.jl",180,"",-1,false,140325172975963),0x00007fa00358d550=>Base.Profile.LineInfo("jl_gc_alloc_1w","/usr/bin/../lib/x86_64-linux-gnu/julia/libjulia.so",-1,"",-1,true,140325227648336),0x00007fa0045a3978=>Base.Profile.LineInfo("simulate","/home/zach/.julia/POMDPToolbox/src/simulators.jl",55, ...
#  ProfileView.TagData(0x00007fa00454bf39,0)   …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)   …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)   …  ProfileView.TagData(0x00007f9dfe44d72f,0)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ⋮                                           ⋱
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)   …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x00007fa00454bf39,0)      ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000000000000,-1)     ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000000000000,-1)     ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000000000000,-1)     ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000000000000,-1)  …  ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000000000000,-1)     ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000000000000,-1)     ProfileView.TagData(0x0000000000000000,-1)
#  ProfileView.TagData(0x0000000000000000,-1)     ProfileView.TagData(0x0000000000000000,-1),12)
