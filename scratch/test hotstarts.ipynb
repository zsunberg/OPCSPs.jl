# %%
using OPCSPs

# %%
include("hotstarts.jl")
# Out:
# solve! (generic function with 1 method)

# %%
op = gen_op(n_nodes=10, rng=MersenneTwister(10));

# %%
mm = create_model(op)
# Out:
# OPModel(Maximization problem with:
#  * 103 linear constraints
#  * 109 variables: 100 binary
# Solver set to Gurobi.Gurobi,:NotSolved)

# %%
@time solve!(mm)
# Out:
# :Optimal
# 0.002939 seconds (61 allocations: 15.219 KB)

# %%
@time solve!(mm)
# Out:
# :Optimal
# 0.002935 seconds (61 allocations: 15.219 KB)

# %%
Profile.clear()
@profile solve!(mm)
# Out:
# :Optimal

# %%
using ProfileView
ProfileView.view()
# Out:
# ProfileView.ProfileData(5423x9 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}:
#  RGB{U8}(0.0,0.0,0.0)        …  RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.0,0.0,0.0)           RGB{U8}(0.0,0.0,0.0)
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.471,0.353,0.988)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.471,0.353,0.988)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.471,0.353,0.988)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.471,0.353,0.988)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.471,0.353,0.988)
#  RGB{U8}(0.471,0.353,0.988)  …  RGB{U8}(0.471,0.353,0.988)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.471,0.353,0.988)
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.471,0.353,0.988)
#  ⋮                           ⋱
#  RGB{U8}(0.471,0.353,0.988)     RGB{U8}(0.471,0.353,0.988)
# ...
